# %%
import json
import cv2 

img = cv2.imread('/home/shankhanil/work/3dclothgen/pipeline/research/automating-panel-colors/T-Shirt_UVMaps_Naming convention.png')

with open('colormaps.json', 'r') as fp:
    colormaps = json.load(fp)

# %%
colormaps
# Out:
# {'PANEL_FALLBACK': [0, 0, 0],
#  'PANEL_FRONT': [40, 92, 6],
#  'PANEL_LEFT': [248, 78, 154],
#  'PANEL_RIGHT_FRONT': [27, 110, 125],
#  'PANEL_RIGHT_BACK': [9, 101, 140],
#  'PANEL_RIGHT_FRONT_UPPER': [23, 82, 92],
#  'PANEL_RIGHT_FRONT_UPPER_OVER': [56, 122, 133],
#  'PANEL_RIGHT_FRONT_UPPER_UNDER': [20, 72, 126],
#  'PANEL_RIGHT_BOTTOM': [135, 85, 119],
#  'PANEL_RIGHT_FRONT_BOTTOM': [22, 89, 100],
#  'PANEL_RIGHT_FRONT_BOTTOM_OVER': [146, 145, 195],
#  'PANEL_RIGHT_FRONT_BOTTOM_UNDER': [118, 117, 149],
#  'PANEL_FRONT_UPPER': [0, 0, 0],
#  'PANEL_FRONT_MIDDLE': [108, 110, 165],
#  'PANEL_FRONT_BOTTOM': [0, 0, 0],
#  'PANEL_FRONT_BOTTOM_OVER': [55, 124, 99],
#  'PANEL_BACK_UPPER': [0, 0, 0],
#  'PANEL_BACK_BOTTOM': [0, 0, 0],
#  'PANEL_BACK_BOTTOM_OVER': [56, 58, 118],
#  'PANEL_LEFT_BACK_UPPER_OVER': [99, 89, 81],
#  'PANEL_LEFT_BACK_UPPER_UNDER': [97, 108, 86],
#  'PANEL_RIGHT_BACK_UPPER': [155, 89, 101],
#  'PANEL_LEFT_BACK_UPPER': [123, 70, 80],
# ...

# %%
import numpy as np


for panel in colormaps.keys():
    # print(panel)
    color = colormaps[panel]
    # print(color)
    check = np.where((img == color).any(axis=-1))

    # if check != ()
    # print(check)
# Out:
# (array([ 293,  293,  293, ..., 8007, 8007, 8007]), array([3072, 3073, 3074, ..., 6572, 6573, 6574]))
# (array([4286, 4286, 4286, ..., 7472, 7472, 7472]), array([5679, 5680, 5681, ..., 4320, 4321, 4322]))
# (array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64))
# (array([], dtype=int64), array([], dtype=int64))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [8], line 8
#       6 color = colormaps[panel]
#       7 # print(color)
# ----> 8 check = np.where((img== color).any(axis=-1))
#      10 print(check)
#
# File <__array_function__ internals>:5, in where(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
# im2 = img.copy()
# gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# import pytesseract


# # Performing OTSU threshold
# ret, thresh1 = cv2.threshold(gray, 0, 255, cv2.THRESH_OTSU | cv2.THRESH_BINARY_INV)

# # Specify structure shape and kernel size.
# # Kernel size increases or decreases the area
# # of the rectangle to be detected.
# # A smaller value like (10, 10) will detect
# # each word instead of a sentence.
# rect_kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (18, 18))

# # Applying dilation on the threshold image
# dilation = cv2.dilate(thresh1, rect_kernel, iterations = 1)

# # Finding contours
# contours, hierarchy = cv2.findContours(dilation, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)


# for cnt in contours:
#     x, y, w, h = cv2.boundingRect(cnt)
#     # Drawing a rectangle on copied image
#     rect = cv2.rectangle(im2, (x, y), (x + w, y + h), (0, 255, 0), 2)
#     # Cropping the text block for giving input to OCR
#     cropped = im2[y:y + h, x:x + w]
#     # Open the file in append mode
#     file = open("recognized.txt", "a")
#     # Apply OCR on the cropped image
#     text = pytesseract.image_to_string(cropped)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [6], line 4
#       1 im2 = img.copy()
#       2 gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# ----> 4 import pytesseract
#       7 # Performing OTSU threshold
#       8 ret, thresh1 = cv2.threshold(gray, 0, 255, cv2.THRESH_OTSU | cv2.THRESH_BINARY_INV)
#
# ModuleNotFoundError: No module named 'pytesseract'
